# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
import numpy as np

# %%
random_list = [random.randint(1,10000) for _ in range(0, 16)]
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 4
for i in range(1, columns*rows +1):
    img = mpimg.imread('/ufrc/cis6930/kunwardeep.singh/GanGenerator/data1/data/train/gan1_data/gan1_{}.png'.format(random_list[i-1]))
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %%
random_list = [random.randint(1,10000) for _ in range(0, 16)]
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 4
for i in range(1, columns*rows +1):
    img = mpimg.imread('/ufrc/cis6930/kunwardeep.singh/GanGenerator/data/train/gan2_data/gan2_{}.png'.format(random_list[i-1]))
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %%
cifar_list = ['2262_bird.png','379_frog.png','5273_horse.png','6929_dog.png','8235_horse.png','9790_ship.png', 
             '2427_dog.png','3894_horse.png','5409_automobile.png','7020_horse.png','839_bird.png','9879_horse.png',
             '2452_bird.png','3919_horse.png','542_frog.png','7029_deer.png']
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 4
for i in range(1, columns*rows +1):
    img = mpimg.imread('/ufrc/cis6930/kunwardeep.singh/GanGenerator/data/validation/cifar/'+ cifar_list[i-1])
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %%
random_list = [random.randint(1,99) for _ in range(0, 16)]
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 4
for i in range(1, columns*rows +1):
    img = mpimg.imread('/home/kunwardeep.singh/dcgan_data/dcgan_{}.png'.format(random_list[i-1]))
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %%
random_list = [random.randint(1,99) for _ in range(0, 16)]
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 4
for i in range(1, columns*rows +1):
    img = mpimg.imread('/home/kunwardeep.singh/gan2_data/gan2_{}.png'.format(random_list[i-1]))
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %%
img1 = mpimg.imread('/home/kunwardeep.singh/dcgan_data/dcgan_1.png')
np.shape(img1)
# Out:
# (32, 32, 4)

# %%
img2 = mpimg.imread('/ufrc/cis6930/kunwardeep.singh/GanGenerator/data/validation/cifar/2262_bird.png')
np.shape(img2)
# Out:
# (32, 32, 3)
